# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
frame=pd.read_csv("G:\\DATA prediction\\spotify_data.csv")

# %%
frame.head(3)
# Out:
#          artist_name              track_name                track_id  \
# 0         Juice WRLD  All Girls Are The Same  4VXIryQMWpIdGgYR4TrjT1
# 1  Schoolgirl Byebye               Year,2015  0UsmyJDsst2xhX1ZiFF3JW
# 2         Juice WRLD            Lucid Dreams  285pBltuF7vW8TeWk8hdRR
#
#    popularity
# 0          83
# 1          25
# 2          84

# %%
df1=frame.set_index('track_id')

# %%
df1.describe()
# Out:
#        popularity
# count  4000.00000
# mean     51.10950
# std      31.08038
# min       0.00000
# 25%      27.00000
# 50%      63.00000
# 75%      80.00000
# max      94.00000

# %%
df1.head(10)
# Out:
#                               artist_name  \
# track_id
# 4VXIryQMWpIdGgYR4TrjT1         Juice WRLD
# 0UsmyJDsst2xhX1ZiFF3JW  Schoolgirl Byebye
# 285pBltuF7vW8TeWk8hdRR         Juice WRLD
# 4fbwTO3DJ2qryMddov9RbB      Fleetwood Mac
# 0rKtyWc8bvkriBthvHKY8d               Joji
# 7AFlWfLvu8ESnVrtHxHpEZ           Revenant
# 6foY66mWZN0pSRjZ408c00      Morgan Wallen
# 1vLPTWPfJSIrqOhNUWNfNY      Frank Sinatra
# 78QR3Wp35dqAhFEc2qAGjE           Lil Baby
# 5nTnApD6zNvuHJe0fXU5Jg      Fleetwood Mac
#
#                                                           track_name  \
# track_id
# 4VXIryQMWpIdGgYR4TrjT1                        All Girls Are The Same
# 0UsmyJDsst2xhX1ZiFF3JW                                     Year,2015
# 285pBltuF7vW8TeWk8hdRR                                  Lucid Dreams
# 4fbwTO3DJ2qryMddov9RbB  Rhiannon (Will You Ever Win) - 2018 Remaster
# 0rKtyWc8bvkriBthvHKY8d                      SLOW DANCING IN THE DARK
# ...

# %%
df1.isnull().sum()
# Out:
# artist_name    0
# track_name     0
# popularity     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 4VXIryQMWpIdGgYR4TrjT1 to 5PjdY0CKGZdEuoNab3yDmX
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  4000 non-null   object
#  1   track_name   4000 non-null   object
#  2   popularity   4000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 125.0+ KB

# %%
df1.head(10)
# Out:
#                               artist_name  \
# track_id
# 4VXIryQMWpIdGgYR4TrjT1         Juice WRLD
# 0UsmyJDsst2xhX1ZiFF3JW  Schoolgirl Byebye
# 285pBltuF7vW8TeWk8hdRR         Juice WRLD
# 4fbwTO3DJ2qryMddov9RbB      Fleetwood Mac
# 0rKtyWc8bvkriBthvHKY8d               Joji
# 7AFlWfLvu8ESnVrtHxHpEZ           Revenant
# 6foY66mWZN0pSRjZ408c00      Morgan Wallen
# 1vLPTWPfJSIrqOhNUWNfNY      Frank Sinatra
# 78QR3Wp35dqAhFEc2qAGjE           Lil Baby
# 5nTnApD6zNvuHJe0fXU5Jg      Fleetwood Mac
#
#                                                           track_name  \
# track_id
# 4VXIryQMWpIdGgYR4TrjT1                        All Girls Are The Same
# 0UsmyJDsst2xhX1ZiFF3JW                                     Year,2015
# 285pBltuF7vW8TeWk8hdRR                                  Lucid Dreams
# 4fbwTO3DJ2qryMddov9RbB  Rhiannon (Will You Ever Win) - 2018 Remaster
# 0rKtyWc8bvkriBthvHKY8d                      SLOW DANCING IN THE DARK
# ...

# %%
 dummies=pd.get_dummies(df1, drop_first=True)

# %%
dummies.head(30)
# Out:
#                         popularity  artist_name_015B  artist_name_03 Greedo  \
# track_id
# 4VXIryQMWpIdGgYR4TrjT1          83                 0                      0
# 0UsmyJDsst2xhX1ZiFF3JW          25                 0                      0
# 285pBltuF7vW8TeWk8hdRR          84                 0                      0
# 4fbwTO3DJ2qryMddov9RbB          49                 0                      0
# 0rKtyWc8bvkriBthvHKY8d          83                 0                      0
# 7AFlWfLvu8ESnVrtHxHpEZ           0                 0                      0
# 6foY66mWZN0pSRjZ408c00          78                 0                      0
# 1vLPTWPfJSIrqOhNUWNfNY          43                 0                      0
# 78QR3Wp35dqAhFEc2qAGjE          80                 0                      0
# 5nTnApD6zNvuHJe0fXU5Jg          46                 0                      0
# 0u2P5u6lvoDfwTYjAADbn4          87                 0                      0
# ...

# %%
X = dummies.drop('popularity', axis = 1)
Y = df1['popularity']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV

MLAlgo = ["Linear Regression", "Ridge Regression", "Lasso Regression"]
clfs = [LinearRegression(), RidgeCV(), LassoCV()]
result = []

for clff in clfs:
    clff.fit(X_train, Y_train)
    acc = clff.score(X_test, Y_test)
    result.append(acc)
    
result_df = pd.DataFrame(result, index = MLAlgo)
result_df.columns = ["Accuracy"]
result_df.sort_values(by = "Accuracy", ascending = False)
# Out:
#                        Accuracy
# Ridge Regression   8.713057e-01
# Lasso Regression   8.340696e-01
# Linear Regression -3.180586e+22
